# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import linear_model


house_data = pd.read_csv(r'D:\dataset\train.csv')

house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
(house_data.corr() > 0.4).sum()
# Out:
# Id                1
# MSSubClass        1
# LotFrontage       4
# LotArea           2
# OverallQual      13
# OverallCond       1
# YearBuilt         8
# YearRemodAdd      7
# MasVnrArea        3
# BsmtFinSF1        4
# BsmtFinSF2        1
# BsmtUnfSF         2
# TotalBsmtSF       9
# 1stFlrSF         11
# 2ndFlrSF          6
# LowQualFinSF      1
# GrLivArea        14
# BsmtFullBath      2
# BsmtHalfBath      1
# FullBath         11
# HalfBath          3
# BedroomAbvGr      4
# KitchenAbvGr      1
# TotRmsAbvGrd      8
# Fireplaces        4
# GarageYrBlt       8
# GarageCars       11
# GarageArea       10
# WoodDeckSF        1
# OpenPorchSF       1
# EnclosedPorch     1
# 3SsnPorch         1
# ScreenPorch       1
# PoolArea          1
# MiscVal           1
# MoSold            1
# YrSold            1
# SalePrice        14
# dtype: int64

# %% [markdown]
# # For Univariate Linear Regression

# %%
from sklearn.model_selection import train_test_split


x = np.array(house_data['GrLivArea'])
y = np.array(house_data['SalePrice'])

x = x.reshape((len(x) , 1))
y = y.reshape((len(x) , 1))

training_data , testing_data , training_data_labels , testing_data_labels  = train_test_split( x , y , test_size = 0.2 , random_state = 5)

print("Trainig Data: " , training_data.shape)

print("training data labels: " , training_data_labels.shape)


print("Testing Data" , testing_data.shape)


print("Testing data labels: " , testing_data_labels.shape)
# Out:
# Trainig Data:  (1168, 1)
# training data labels:  (1168, 1)
# Testing Data (292, 1)
# Testing data labels:  (292, 1)

# %%
from sklearn import linear_model

model = linear_model.LinearRegression()


model.fit(training_data , training_data_labels)
# Out:
# LinearRegression()

# %%
plt.scatter(training_data , training_data_labels , color = 'orange' , marker = 'o' , label = 'Data Points')

plt.plot(training_data , model.predict(training_data) , color = 'green' , label = 'Regression Line')

plt.legend()

# %%
result = model.predict(testing_data)

result
# Out:
# array([[205723.55398565],
#        [190288.66390983],
#        [249983.86791166],
#        [160747.71535413],
#        [175160.42727923],
#        [169538.44745029],
#        [164223.12106656],
#        [165551.95266249],
#        [184564.46626582],
#        [213492.10793109],
#        [186097.73349189],
#        [170765.06123115],
#        [265520.97580255],
#        [105754.53084559],
#        [175978.1697998 ],
#        [178533.61517659],
#        [118429.53991447],
#        [179964.66458759],
#        [177715.87265602],
#        [204088.0689445 ],
#        [201634.84138278],
#        [239353.21514421],
#        [142757.37990152],
#        [170969.49686129],
#        [175058.20946416],
#        [121904.94562691],
#        [245077.41278823],
#        [198159.43567035],
#        [245384.06623344],
#        [224633.8497739 ],
#        [194581.81214284],
#        [196217.29718398],
#        [169334.01182014],
#        [128038.0145312 ],
#        [145619.47872352],
# ...

# %%
from sklearn.metrics import accuracy_score , r2_score

r2 = r2_score(testing_data_labels, result)

r2
# Out:
# 0.5975647395439107

# %%
accuracy = model.score(testing_data, testing_data_labels)

accuracy
# Out:
# 0.5975647395439107

# %%
model.coef_
# Out:
# array([[102.21781507]])

# %% [markdown]
# model.intercept_

# %% [markdown]
# ## Multivariate Linear Regression

# %%
house_data = pd.read_csv(r'D:\dataset\train.csv')

house_data

house_data.dropna(axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
dfnew = house_data.select_dtypes(include=np.number)

dfnew
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
dfnew.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
s =  (dfnew.corr() > 0.4).sum() 

print(len(s))
# Out:
# 38

# %%
newdfnew = dfnew.dropna(axis = 1)

# %%
newdfnew.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

x = np.array(newdfnew[['GrLivArea' , 'OverallQual' , '1stFlrSF' , 'GarageCars' , 'GarageArea' , 'Id' , 'MSSubClass' , 'OverallCond'  , 'YearRemodAdd'  , 'BsmtFinSF1' , 'BsmtFinSF2' , 'BsmtUnfSF' , 'TotalBsmtSF' ,'2ndFlrSF' , 'LowQualFinSF' , 'BsmtFullBath' , 'BsmtHalfBath' , 'FullBath' , 'HalfBath' , 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd' , 'Fireplaces'  , 'WoodDeckSF' , 'OpenPorchSF' , 'EnclosedPorch' , '3SsnPorch' , 'ScreenPorch' , 'PoolArea' , 'MiscVal' , 'MoSold' , 'YrSold']])

#x = np.array(dfnew)
y = np.array(newdfnew['SalePrice'])


training_data , testing_data , training_data_labels , testing_data_labels  = train_test_split( x , y , test_size = 0.2 , random_state = 5)


print("Trainig Data: " , training_data.shape)

print("training data labels: " , training_data_labels.shape)


print("Testing Data" , testing_data.shape)


print("Testing data labels: " , testing_data_labels.shape)
# Out:
# Trainig Data:  (1168, 32)
# training data labels:  (1168,)
# Testing Data (292, 32)
# Testing data labels:  (292,)

# %%
x.isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8420/1723639372.py in <module>
# ----> 1 x.isnull()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'isnull'

# %%
model = linear_model.LinearRegression()

model.fit(training_data,training_data_labels)
# Out:
# LinearRegression()

# %%
result = model.predict(testing_data)

result
# Out:
# array([228144.73380063, 190990.76770225, 151162.62032853,  83439.38303358,
#        144008.47173478, 200008.45981679, 179084.56811415, 141335.53612476,
#        274152.65862746, 220074.01526966, 130273.52307697, 159564.01186589,
#        260880.79737161, 100964.81911934, 163143.82454421, 226692.65759797,
#        118368.82173176, 179363.424371  , 210731.39395056, 229701.65679546,
#        208177.59539696, 258180.53889361, 149862.03922214, 196932.17151501,
#        246578.76386167,  95986.48480059, 323054.84239477, 254294.82966545,
#        258597.50452893, 247444.45216242, 245371.43330466, 183466.47091982,
#        118485.36198867, 107875.00941674,  87532.1470668 , 258741.69293965,
#        181641.01951689, 207159.40426528,  96292.84167683,  83633.93399698,
#        248485.0074975 , 172281.85917652, 130989.37501906, 257338.38081357,
#        149605.10727413, 255101.31347724, 196304.29246337, 108026.15106585,
# ...

# %%
from sklearn.metrics import accuracy_score , r2_score

r2 = r2_score(testing_data_labels, result)

r2
# Out:
# 0.8140575104241572

# %%
accuracy = model.score(testing_data, testing_data_labels)

accuracy
# Out:
# 0.8140575104241572

# %%
x = (house_data[['GrLivArea' , 'OverallQual' , '1stFlrSF' , 'GarageCars' , 'GarageArea' ]])
y = (house_data['SalePrice'])

plt.scatter(x['GrLivArea'] , y , color = 'orange' ,   label = 'GrLivArea')
plt.scatter(x['OverallQual'] , y , color = 'green'  , label = 'OverallQual')
plt.scatter(x['1stFlrSF'] , y , color = 'blue'  , label = '1stFlrSF')
plt.scatter(x['GarageCars'] , y , color = 'pink'  , label = 'GarageCars')
plt.scatter(x['GarageArea'] , y , color = 'black'  , label = 'GarageArea')

plt.plot(training_data , model.predict(training_data) , color = 'purple' , label = 'Regression Line')

plt.legend()

# %% [markdown]
# ## Polynomial Linear Regression

# %%
from sklearn import linear_model

from sklearn.model_selection import train_test_split


from sklearn.preprocessing import PolynomialFeatures

house_data = pd.read_csv(r'D:\dataset\train.csv')

house_data

x = (house_data[['GrLivArea' , 'OverallQual' , '1stFlrSF' , 'GarageCars' , 'GarageArea' , 'TotalBsmtSF']])
y = (house_data['SalePrice'])

training_data , testing_data , training_data_labels , testing_data_labels  = train_test_split( x , y , test_size = 0.2 , random_state = 5)


poly_features = PolynomialFeatures(degree = 2)

x_poly = poly_features.fit_transform(training_data)

x_test_poly = poly_features.fit_transform(testing_data)



model = linear_model.LinearRegression()

model.fit(x_poly , training_data_labels)

y2_pred = model.predict(x_test_poly)

# %%
y2_pred
# Out:
# array([225299.8626272 , 200161.28849846, 185779.40972341, 110515.53180554,
#        141186.62375159, 210182.4167721 , 181153.35276447, 145138.29943053,
#        276217.31380813, 212380.7488132 , 139695.33904444, 152757.64174773,
#        235975.1314944 , 103573.27253438, 154867.09210623, 243819.76874141,
#        123898.70578093, 194052.3628927 , 191570.68223311, 195536.75194082,
#        203221.58060094, 234299.51512819, 146512.40341256, 211682.18014296,
#        267087.27428473, 111038.96383489, 340617.98838949, 292384.88027577,
#        256738.73154863, 210752.99809322, 257218.33582982, 175154.15047946,
#        139149.90303327, 125406.58213088, 114995.74971994, 265440.01121996,
#        155779.95321562, 220800.08569547, 115965.12922418,  85523.58317293,
#        226336.77898801, 164039.95695584, 127935.30245347, 230356.86071178,
#        152984.14297292, 244399.54002079, 194397.17797094, 121430.72938166,
# ...

# %%
from sklearn.metrics import accuracy_score , r2_score

accuracy = r2_score( y2_pred , testing_data_labels)
accuracy
# Out:
# 0.8380307744246207

# %% [markdown]
# ## Scaling on Univariate Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import linear_model
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , r2_score
from sklearn.preprocessing import StandardScaler



from sklearn.preprocessing import PolynomialFeatures

house_data = pd.read_csv(r'D:\dataset\train.csv')

house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
x = np.array(house_data['GrLivArea'])

y = np.array(house_data['SalePrice'])


x = x.reshape((len(x) , 1))
y = y.reshape((len(x) , 1))



training_data , testing_data , training_data_labels , testing_data_labels = train_test_split ( x , y , test_size = 0.2 , shuffle = 'True' ,  random_state = 5)

# %%
scaling = StandardScaler()

scaling_training_data = scaling.fit_transform(training_data)


scaling_tesing_data = scaling.fit_transform(testing_data)

# %%
model = linear_model.LinearRegression()

model.fit(scaling_training_data , training_data_labels)
# Out:
# LinearRegression()

# %%
result = model.predict(scaling_tesing_data)

result
# Out:
# array([[211232.90118375],
#        [194367.22428544],
#        [259596.06738884],
#        [162087.88240722],
#        [177836.62706061],
#        [171693.49971354],
#        [165885.45203995],
#        [167337.46395835],
#        [188112.40371389],
#        [219721.58624515],
#        [189787.80208127],
#        [173033.81840745],
#        [276573.43751164],
#        [101996.92763046],
#        [178730.17285655],
#        [181522.50346885],
#        [115846.88746748],
#        [183086.20861174],
#        [180628.95767291],
#        [209445.80959188],
#        [206765.17220407],
#        [247979.97204166],
#        [142429.87489661],
#        [173257.20485643],
#        [177724.93383612],
#        [119644.45710022],
#        [254234.79261322],
#        [202967.60257134],
#        [254569.8722867 ],
#        [231896.1477148 ],
#        [199058.33971411],
#        [200845.43130599],
#        [171470.11326456],
#        [126346.05056974],
#        [145557.28518239],
# ...

# %%
from sklearn.metrics import accuracy_score , r2_score


r2 = r2_score(testing_data_labels , result )

r2
# Out:
# 0.6176124934127378

# %% [markdown]
# ## Multi-variate Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import linear_model
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , r2_score
from sklearn.preprocessing import StandardScaler



from sklearn.preprocessing import PolynomialFeatures

house_data = pd.read_csv(r'D:\dataset\train.csv')

house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
x = (house_data[['GrLivArea' , 'OverallQual' , '1stFlrSF' , 'GarageCars' , 'GarageArea' , 'TotalBsmtSF']])

y = (house_data['SalePrice'])

training_data , testing_data , training_data_labels , testing_data_labels = train_test_split ( x , y , test_size = 0.2 , shuffle = 'True' ,  random_state = 5)

# %%
scaling = StandardScaler()

scaling_training_data = scaling.fit_transform(training_data)


scaling_tesing_data = scaling.fit_transform(testing_data)

# %%
model = linear_model.LinearRegression()

model.fit(scaling_training_data , training_data_labels)
# Out:
# LinearRegression()

# %%
result = model.predict(scaling_tesing_data)

result
# Out:
# array([232958.11563492, 204459.64818893, 205040.73355402,  89448.8207132 ,
#        145008.94818558, 212996.6835362 , 183970.36445702, 147440.74817377,
#        274256.88195896, 222316.88853527, 135468.48366544, 161676.32019006,
#        233970.88865843, 117565.40048981, 173881.9906655 , 244471.14188658,
#        125941.54677408, 196001.88823478, 195658.68039653, 226902.66924696,
#        206702.95646592, 230657.83546467, 146797.76746949, 213845.32293729,
#        265253.19901625,  83205.26718054, 314093.64078991, 280642.0310919 ,
#        256862.96395961, 209409.81173067, 252787.57223069, 178824.86023827,
#        145264.78607837, 112212.9616065 ,  89649.9407934 , 256876.05558106,
#        163985.67184602, 222197.04079519, 103583.23177602,  80946.36832186,
#        222198.11211958, 167936.75808304, 114668.15560931, 229273.6021957 ,
#        162776.51353271, 239237.17995655, 191311.31916751, 108335.06046854,
# ...

# %%
from sklearn.metrics import accuracy_score , r2_score


r2 = r2_score(testing_data_labels , result )

r2
# Out:
# 0.800762973572246

# %% [markdown]
# ## Scaling On Polynomial Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import linear_model
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , r2_score
from sklearn.preprocessing import StandardScaler



from sklearn.preprocessing import PolynomialFeatures

house_data = pd.read_csv(r'D:\dataset\train.csv')

house_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
x = (house_data[['GrLivArea' , 'OverallQual' , '1stFlrSF' , 'GarageCars' , 'GarageArea' , 'TotalBsmtSF']])

y = (house_data['SalePrice'])

training_data , testing_data , training_data_labels , testing_data_labels = train_test_split ( x , y , test_size = 0.2 , shuffle = 'True' ,  random_state = 5)

# %%
x.shape
# Out:
# (1460, 6)

# %%
y.shape
# Out:
# (1460,)

# %%
scaling = StandardScaler()

scaling_training_data = scaling.fit_transform(training_data)


scaling_tesing_data = scaling.fit_transform(testing_data)

# %%
poly_features = PolynomialFeatures(degree = 2)

polynomial_training_data = poly_features.fit_transform(scaling_training_data)

polynomial_testing_data = poly_features.fit_transform(scaling_tesing_data)



model = linear_model.LinearRegression()

model.fit(polynomial_training_data , training_data_labels)

result = model.predict(polynomial_testing_data)

# %%
result
# Out:
# array([227627.96995673, 198333.5672613 , 183979.90931881, 109226.40603864,
#        139556.44022494, 209132.01012043, 179886.20382842, 143474.34633467,
#        276392.33639892, 209298.13268204, 138044.87072998, 152230.00187128,
#        238679.71642633,  99241.09951936, 152780.2404832 , 243271.21861576,
#        121969.39902995, 192718.05033953, 189977.16227174, 195693.59534228,
#        204714.4292053 , 236120.66829569, 144162.53034309, 210673.22789615,
#        268012.97573216, 109794.67595807, 344810.38203478, 292914.1614919 ,
#        253544.8073931 , 211446.59362049, 256824.62723715, 175592.3558927 ,
#        137004.59231618, 123414.43522325, 113777.07704374, 264976.45028857,
#        155349.99165343, 219517.45692816, 113541.73297813,  80968.28303175,
#        228884.93330719, 164467.7699715 , 126043.94663131, 231635.30790793,
#        150956.08492535, 246585.39069563, 200256.23039625, 119318.88728743,
# ...

# %%
from sklearn.metrics import accuracy_score , r2_score


r2 = r2_score(testing_data_labels , result )

r2
# Out:
# 0.8678904738372477

# %% [markdown]
# ## MinMax on Linear Regression With Ploynomial Linear Regression

# %%
from sklearn.preprocessing import MinMaxScaler


scaling = MinMaxScaler()

scaling_training_data = scaling.fit_transform(training_data)


scaling_tesing_data = scaling.fit_transform(testing_data)

# %%
poly_features = PolynomialFeatures(degree = 2)

polynomial_training_data = poly_features.fit_transform(scaling_training_data)

polynomial_testing_data = poly_features.fit_transform(scaling_tesing_data)



model = linear_model.LinearRegression()

model.fit(polynomial_training_data , training_data_labels)

result = model.predict(polynomial_testing_data)

# %%
result
# Out:
# array([338575.76226277, 252326.71178187, 248827.4754597 , 126690.97134361,
#        204453.88371347, 318930.81646594, 251988.36597568, 195610.80171079,
#        469225.55083153, 242992.83299753, 165618.63963336, 214851.99667781,
#        300175.32665714, 179995.2512687 , 245463.6875769 , 393596.65399305,
#        162060.27765653, 257807.10831366, 246834.44472841, 301788.08483448,
#        285261.31101429, 298081.38009255, 226122.99365863, 321624.42990023,
#        393021.65041102, 132570.45947787, 488247.29659779, 425441.80641057,
#        390825.34366979, 220204.03394989, 417843.41390774, 228915.33124695,
#        199152.83990561, 174687.58233074, 156368.56038075, 416933.3739514 ,
#        217760.8156806 , 312823.8589467 , 165866.84986327, 130591.6320376 ,
#        308691.06140309, 226163.41197618, 177107.57706202, 302828.69835209,
#        224647.67519027, 298994.26366937, 268418.16981064, 163106.92510286,
# ...

# %%
from sklearn.metrics import accuracy_score , r2_score


r2 = r2_score(testing_data_labels , result )

r2
# Out:
# 0.8678904738372477
